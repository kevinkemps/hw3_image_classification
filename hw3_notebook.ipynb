# %%
from keras.datasets import cifar10
# load the dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from keras.datasets import cifar10
#       2 # load the dataset
#       3 (X_train, y_train), (X_test, y_test) = cifar10.load_data()
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\_tf_keras\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\activations\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.src.activations import deserialize
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\__init__.py:10
#       7     import torch
#       9 from keras.src.backend.common.dtypes import result_type
# ---> 10 from keras.src.backend.common.keras_tensor import KerasTensor
#      11 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#      12 from keras.src.backend.common.keras_tensor import is_keras_tensor
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\keras_tensor.py:2
#       1 from keras.src.api_export import keras_export
# ----> 2 from keras.src.utils import tree
#       3 from keras.src.utils.naming import auto_name
#       6 @keras_export("keras.KerasTensor")
#       7 class KerasTensor:
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\tree.py:12
#      10 # Register backend-specific node classes
#      11 if backend() == "tensorflow":
# ---> 12     from tensorflow.python.trackable.data_structures import ListWrapper
#      14     optree.register_pytree_node(
#      15         ListWrapper,
#      16         lambda x: (x, None),
#      17         lambda metadata, children: ListWrapper(list(children)),
#      18         namespace="keras",
#      19     )
#      22 @keras_export("keras.tree.is_nested")
#      23 def is_nested(structure):
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from skimage.color import rgb2gray
# convert to grayscale images
X_train = rgb2gray(X_train)
X_test = rgb2gray(X_test)
